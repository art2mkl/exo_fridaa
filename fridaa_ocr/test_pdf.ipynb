# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract

from pdf2image import convert_from_path
import os
import cv2
import re

import pandas as pd

from fuzzysearch import find_near_matches
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
class Extract_data_from_pdf:
    
    def __init__(self, pdf_path, keywords_path):
        
        # Config software path (OCR, POPPLER) and catch length
        self.pytesseract_path = r'/usr/local/bin/tesseract'
        self.poppler_path = r'/usr/local/Cellar/poppler/21.09.0/bin'
        self.catch_length = 20
        self.txt = ""
        self.image_file_path = r'img_files/'
        
        # Create list of images after converting pdf in image 
        self.list_jpg = self.pdf_to_img(pdf_path)
        
        
        self.df = pd.read_excel(keywords_path)
        self.banks = self.df.columns[1:]
        self.extract_basic()
        self.choose_bank()
        self.keywords = self.df[self.bank].tolist()
        self.export_data = pd.DataFrame([self.export_result()], columns = self.df['variables'].tolist()).assign(banque=self.bank)
    
    #--------------------------------------------------------------------------------------------#  
    def extract_basic(self):
        """
        Extract string with basic scan of each pages from pdf
        @print string
        @return none
        """
        final_txt=''
        for item_jpg in self.list_jpg:
            add_string = self.img_to_string(item_jpg)
            final_txt = final_txt+f'\n page_{self.list_jpg.index(item_jpg)+1}\n'+add_string
            
        self.txt = final_txt
        #print(self.txt)
        
    #--------------------------------------------------------------------------------------------#
    def choose_bank(self):
        """
        Select bank name in string file
        @return none
        """
        for i in self.banks:
            if i in self.txt:
                self.bank = i
                break
    
    #--------------------------------------------------------------------------------------------#
    def img_to_string(self, img_path):
        """
        Scan element to string
        @return string with all scan
        """
        pytesseract.pytesseract.tesseract_cmd = self.pytesseract_path
        return pytesseract.image_to_string(Image.open(img_path))
    
    #--------------------------------------------------------------------------------------------#
    def pdf_to_img(self, pdf_path):
        """
        Convert and save all pdf pages in jpeg files
        @return list of jpeg files
        """
       
        pages = convert_from_path(pdf_path, 350,
                                  
                                  #xxxxx delete this line on linux distribution xxxxxxx
                                  poppler_path = self.poppler_path
                                  #xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
                                 )
        
        i = 1
        name = os.path.basename(pdf_path).split('.')[0]
        tab_jpg = []
        
        for page in pages:
            image_name = self.image_file_path + name + str(i) + ".jpg"  
            page.save(image_name, "JPEG")
            i = i+1
            tab_jpg.append(image_name)
        
        return tab_jpg
    
    #--------------------------------------------------------------------------------------------#
    def catch_result(self, key_word):
        """
        Select on scan best keyword matches compare to knowledge_base and extract numerical value associated
        @return numerical value or "Not found"
        """
    
        results = find_near_matches( key_word, self.txt, max_l_dist = 1)
        if len(results) != 0:
            results_score = [fuzz.token_sort_ratio(key_word, i.matched) for i in results]

            start = results[results_score.index(max(results_score))].end
            final_list = re.findall('\d+[\d\s,.]\d+|[\d\s,.]\d+|\d', self.txt[start:start + self.catch_length].replace(' ',''))
            if len(final_list) == 0:
                return "Not found"

            else:
                return final_list[0]
        else:
            return "Not found"
        
    #--------------------------------------------------------------------------------------------#
    def export_result(self):
        """
        Create a list of catched results
        @return list
        """
        return [self.catch_result(i) for i in self.keywords]

# %%
knowledge_base = 'knowledge_base/alim_keywords.xlsx'
pdf_file = 'pdf_files/CIC.pdf'

# %%
test = Extract_data_from_pdf(pdf_file, knowledge_base)

# %%
print(test.txt)
# Out:
#  page_1
# 19523 Le 07 Avril 2017
# BANQUE CIC SUD OUEST
#
#
#
# Document fourni a titre indicatif sur la base des conditions en vigueur a ce jour - sous réserve de justification des
# informations fournies et du respect de la réglementation en cours - Ce document ne constitue pas un accord de
# crédit, ni une offre de prét. Etude valable 6 jours
#
# Montants exprimés en Euros
#
#
#
#
#
#
# Rachat d'un prét accordé par la banque Crédit Agricole le 29/08/2015 et destiné Initialement au financement
# d'une maison d'une surface habitable de 100 m? comprenant 4 piéces a titre de résidence principale des
# emprunteurs et travaux & hauteur de 10000€
#
#
#
#
#
#
#
#
#
# Coit total de l'opération :
# Apport personnel :
# Montant a financer :
# Durée maximum :
# Taux effort : 31,170 %
# Taux moyen calculé : 1,831 %
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 866,41
#
#
#
# Charges de remboursement maxi de l'investissement
# Montant de l’APL prévisionnel
#
# Charges de J'investissement aprés déduction de APL
# Total des charges (hors impéts)
#
# Total des revenus (aprés l'investissement)
#
# Taux d’effart maxi aprés Investissement (hors impdts)
# Reste 4 vivre (aprés impéts
#
#
#
#
#
#
#
#
#
# 866,41
# 4 055,92
# 3 388,00
#
# 31,170 %
#
# 2 332,08
#
#
#
#
#
#
#
#
# Plan de financement calculé sur la base de la déclaration de l'emprunteur et sous réserve de lagrément de
# l'assurance. Pour APL prévisionnelle, prendre contact avec la CAF ou la CMSA (en attendant les nouvelles modalltés
#
# de calcul).
#
# Les frais de garantie pris en compte ne constituent qu'une simple estimation : le montant exact de ces frais sera
#
# précisé ultérieurement lors de la mise en place des garanties.
#
# Page 1/4 Référence dossier : 1300000002401 124
#
#  page_2
# FADOOR personnel of ass aimilé:
#
# Apport personnel retenu :
# Sait 0,000 % du coft total de l'opération
#
# 0} Prétrelais :
#
# Rachat de prat
# Autre
# Total 174 932,80] Total
#
# Frais annexes estinés de: Préts :
#
# Réglemeniés ot Eparane Logement
# Prats PC/PCAS
#
# Prat PEL
#
# Prat CEL
#
# Prét a Taux Zé6ro
#
# Eco-prét a taux z6ro
#
# Relals ot autres prats
# Relais ,
# CIC IMMO Prat modulable 29,876 %
# ClO JMMO Prét modulable 70,124 %
# Total frals annexes ,00| Total prats (hors relals) F 100,000 %
# Frals d’Intermédlation :
# Frals de garantie :
# Autres prestations :
# Frals de dossier :
#
# CIC IMMO Prét modulable 56 000,00 4,400 % 180 mots 6 118,24
# Fixe
#
# CIC IMMO Prat madulable 131439,80 1,950% 280 mois 37 339,80
# Fixe
#
# PALIER N°01 - §10,21 180 mois
# PALIER N°02 866,41 100 mols
#
# Totaux :
# Colt total préts du Préteur (3) ; 55 155,24
# Durée maxi du plan de financement
#
# (1) Faux hors assurance - (2) Echéance avec assurance groupe ~— (3) Intéréts + Assurance groupe
#
# Plan de remboursement {y compris prét :
# 866,41 pendant 280 mois
#
# Assurances ;
# Déces at Parte Totale et Irréversible d'Autonornie a au eur de 4100 %
#
# Incapacité ternporaire totale de travall supérieure 4 90 jours & hauteur de
# 100 %
#
# Invatidité permanente & hauteur de 100 %
#
# vv ESSA : Décés et Perte Totale et Irréversiole d'Autonomie & hauteur de 100 %
# Incapacité temporaire totale de travail supérieure 4 90 jours & hauteur de
# 100 %
# Invalidité permanente a hauteur de 100 %
#
#
#
#
#
# Page 2/4 Référence dossier ; 1300000002401124
#
#
#
#
#
#  page_3
#
#
# pD arte Totale ot Irréversible d'Autonomie a haute 00 %
# Incapacité temporaire totale de travail supérieure 4 90 jours a hauteur de
# 400 %
#
# Invalldité permanente a hauteur de 100 %
#
# Décds et Perte Totale et Irréversible d’Autonomle 4 hauteur de 100 %
# Incapacité temporaire totale de travall supérieure a 90 jours & hauteur de
# 100 %
#
# Invalidité permanente a hauteur de 100 %
#
#
#
# Garantle{s}
#
#
#
#
#
# egution personne morale |
# caution personne morala
#
#
#
#
#
# Pour nous permettre de rapidement finaliser votre demande de financement, nous vous remercions de bien vouloir nous
# communiquer les documents sulvanis ;
#
# il
# ( Place d'identité des emprunteurs OU pour les étrangers ressortissant d'un Etat non membre de "'U.E. : un titre de séjour en
# cours de validité ;
# 4 Justificatifs de ta situation familfale (copie du Livret de farnille,...)
# O Contrat de mariage’ / PACS (le cas échéant)
#
# Revenus
#
# Q 3derniers bulletins de salalre at/ou justificatifs de pension pour chaque emprunteur
#
# C1 Justificatifs des 6ventuelles autres ressources, CAF, revenus étrangers, pensions, ete...
# ) 3 derniers bilans ou déclaration 2035 (si BNC)
#
# Q Compte d'exploitation certifié (si commergants, artisans, agriculteurs)
#
# ) 2 derniéres déclarations 2044 {si revenus fonciers)
#
# Charges
# O Offres et tableau(x} c'amortissement du/des prét(s} externe(s) en cours
# O Justificatifs des éventualles autres charges, pensions alimentaires, etc...
#
# Fiscalité
# 0 Avis d'iimposition (ou de non-lmposition) N sur les revenus N-1 OU Déclaration de revenus (selon la période de f'année) OU
#
# Justiflcatif du revenu annuel (selon la période de l'année)
#
# Q Avis d’imposition (ou de non-imposition) N-1 sur les revenus N-2 pour toutes les personnes du ménage (soit avis a leur propre
# nom, solt déclaration sur ['honneur de rattachement a un autre foyer fiscal accompagneé de l'avis de ce foyer fiscal)
#
# Q Déclaration 2035 (si BNC)
#
# QO Déclaration ISF (le cas échéant)
#
# Extrait de compte
# CG Relevé de cornpte ou mouvements des 3 derniers mois
#
# (] Justificatifs des avoirs externes
#
# Projet
#
# Ql Titre de propriété
#
# Offre du/des préts immobiliers d'origine (avec les conditions générales ou le cahler des charges pour calculer le mantant des
# pénalités et vérifier les préavis)
#
# O Tableau(x) d'amortissement du/des prét(s) d'origine
#
# (1 Décompte des préts remboursés
#
# Ci Confirmation écrite du préteur d'origine que le prét est remboursé
#
# Financement
#
# © Demande de crédit signée par tous les emprunteurs
#
# Avertissement :
# Les piécas a fournir doivent étre exactes et complétes et nous étre communiquées sous 15 jours.
#
# Page 3/4 Référence dossier : 1360000002401124
#
#  page_4
# En cas de refus de communication des piéces permettant I’6tude de la solvabillt6, nous vous informons que le crédit ne pourra étre
# accordé.
#
# Votre dossier est suivi par;
#
#
#
# eCICLETAILLAN
#
# N’hésitez pas 4 nous recontacter au :
#
# La convention AERAS est destinée 4 faciliter I'accés a 'assurance et a 'emprunt des personnes présentant un risque de santé aggravé.
# 2 vous souhaltez plus d'information vous pouvez en parler a volre chargé de cliantéle ou téléphoner au n° 0 820 377 377 (Service 0,12
# min + prix appel),
#
# Pour les préts immobiliers sournis aux articles L.313-1 et suivants du code de ja consommation, i! est rappeléd que l'emprunteur
# dispose d'un délai de réflexion de dix jours, que la vente est subordonnée a Pobtention du prét et que si celul-ci n'est pas ntti fe
# vendeur doit lul rembourser les sommes versées.
#
#
#
# Page 4/4 Référence dossier : 1300000002401124

# %%
pytesseract. get_tesseract_version()
# Out:
# LooseVersion ('4.1.1
#  leptonica-1.81.1
#   libgif 5.2.1 : libjpeg 9d : libpng 1.6.37 : libtiff 4.3.0 : zlib 1.2.11 : libwebp 1.2.1 : libopenjp2 2.4.0
#  Found AVX2
#  Found AVX
#  Found FMA
#  Found SSE
# ')
